# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanmchavez/Analisisdedatos/blob/main/CodigoCIIIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from PIL import Image
import os

class DataLoader:
    def __init__(self, csv_file_path='/content/drive/MyDrive/instagram_data.csv', image_dir='/content/drive/MyDrive/instagram_data.csv'): # Use './' to denote the current directory
        """
        Initialize the DataLoader.
        Args:
            csv_file_path (str): Path to the CSV file containing image URLs and likes.
            image_dir (str): Path to the directory containing the images.
        """
        # If __file__ is not defined, assume the CSV file is in the current working directory
        try:
            csv_file_path_full = os.path.join(os.path.dirname(__file__), csv_file_path)
        except NameError:
            csv_file_path_full = csv_file_path
        self.data = pd.read_csv(csv_file_path_full)
        self.image_dir = image_dir
        self.images_path = self.data['imageUrl'].tolist()
        self.labels = self.data['likes'].apply(self._classify_likes).tolist()

    def _classify_likes(self, likes):
        # Clasificar en base a "likes"
        return 1 if likes > 10000 else 0

    def _load_image(self, image_path, image_size=(224, 224)):
        # Cargar y preprocesar imagen usando Pillow
        try:
            img = Image.open(f"{self.image_dir}/{image_path}").convert("RGB")
            img = img.resize(image_size)
            img_array = np.array(img) / 255.0  # Normalizar entre 0 y 1
            return img_array
        except Exception as e:
            print(f"Error loading image {image_path}: {e}")
            return np.zeros((*image_size, 3))  # Devolver imagen vacía en caso de error

    def get_image_dataset(self, batch_size=32, image_size=(224, 224)):
        # Crear dataset de imágenes y etiquetas
        images = []
        for image_path in self.images_path:
            img = self._load_image(image_path, image_size)
            images.append(img)

        # Convertir listas a tensores
        images_tensor = tf.convert_to_tensor(images, dtype=tf.float32)
        labels_tensor = tf.convert_to_tensor(self.labels, dtype=tf.int32)

        # Crear dataset
        dataset = tf.data.Dataset.from_tensor_slices((images_tensor, labels_tensor))
        dataset = dataset.batch(batch_size).shuffle(buffer_size=100)
        return dataset

# %%
 def summary(self):
        # Resumen del conjunto de datos
        print("Dataset Summary:")
        print(f"Total records: {len(self.data)}")
        print(f"High engagement posts: {(self.data['likes'] > 10000).sum()}")
        print(f"Low engagement posts: {(self.data['likes'] <= 10000).sum()}")
        print(self.data.describe())
        print("\n")

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from PIL import Image
import os
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Concatenate, Embedding, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
class DataLoader:
    def __init__(self, csv_file_path='/content/drive/MyDrive/instagram_data.csv', image_dir='/content/drive/MyDrive/instagram_data.csv'):
        self.data = pd.read_csv(csv_file_path)
        self.image_dir = image_dir
        self.images_path = self.data['imageUrl'].tolist()
        self.captions = self.data['caption'].tolist()
        # Convert the 'likes' column to numeric before applying the classification function
        self.data['likes'] = pd.to_numeric(self.data['likes'], errors='coerce')
        self.labels = self.data['likes'].apply(self._classify_likes).tolist()
        self.tokenizer = None

    def _classify_likes(self, likes):
        return 1 if likes > 10000 else 0

    def _load_image(self, image_path, image_size=(224, 224)):
        try:
            img = Image.open(f"{self.image_dir}/{image_path}").convert("RGB")
            img = img.resize(image_size)
            img_array = np.array(img) / 255.0
            return img_array
        except Exception as e:
            print(f"Error loading image {image_path}: {e}")
            return np.zeros((*image_size, 3))

    def prepare_text_data(self, max_words=10000, max_length=100):
        self.tokenizer = Tokenizer(num_words=max_words)
        self.tokenizer.fit_on_texts(self.captions)
        sequences = self.tokenizer.texts_to_sequences(self.captions)
        padded_sequences = pad_sequences(sequences, maxlen=max_length)
        return padded_sequences

    def get_image_text_dataset(self, batch_size=32, image_size=(224, 224), max_words=10000, max_length=100):
        images = [self._load_image(img_path, image_size) for img_path in self.images_path]
        padded_sequences = self.prepare_text_data(max_words, max_length)

        images_tensor = tf.convert_to_tensor(images, dtype=tf.float32)
        captions_tensor = tf.convert_to_tensor(padded_sequences, dtype=tf.int32)
        labels_tensor = tf.convert_to_tensor(self.labels, dtype=tf.int32)

        dataset = tf.data.Dataset.from_tensor_slices(((images_tensor, captions_tensor), labels_tensor))
        dataset = dataset.batch(batch_size).shuffle(buffer_size=100)
        return dataset

# %%
def create_model(image_shape=(224, 224, 3), max_words=10000, max_length=100):
    # Image input
    image_input = Input(shape=image_shape, name="image_input")
    x = tf.keras.applications.MobileNetV2(input_shape=image_shape, include_top=False, weights="imagenet")(image_input)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)

    # Text input
    text_input = Input(shape=(max_length,), name="text_input")
    embedding = Embedding(input_dim=max_words, output_dim=50, input_length=max_length)(text_input)
    y = LSTM(64)(embedding)
    y = Dense(64, activation='relu')(y)

    # Concatenate image and text features
    combined = Concatenate()([x, y])
    z = Dense(64, activation='relu')(combined)
    z = Dropout(0.5)(z)
    output = Dense(1, activation='sigmoid')(z)

    model = Model(inputs=[image_input, text_input], outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
def predict_success(model, tokenizer, image_path, caption, image_size=(224, 224), max_length=100):
    # Preprocess the image
    img = Image.open(image_path).convert("RGB")
    img = img.resize(image_size)
    img_array = np.array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    # Preprocess the caption
    sequence = tokenizer.texts_to_sequences([caption])
    padded_sequence = pad_sequences(sequence, maxlen=max_length)

    # Make the prediction
    prediction = model.predict([img_array, padded_sequence])[0][0]
    if prediction > 0.5:
        print(f"The post is likely to get more than 10,000 likes ({prediction * 100:.2f}% probability).")
    else:
        print(f"The post is likely to get less than 10,000 likes ({(1 - prediction) * 100:.2f}% probability).")

# %%
if __name__ == "__main__":
    # Load data and create dataset
    data_loader = DataLoader()
    dataset = data_loader.get_image_text_dataset()

    # Build and train the model
    model = create_model()
    model.fit(dataset, epochs=5)

    # Predict on a new image and caption
    image_path = input("Please upload your image file path: ")
    caption = input("Please enter the caption (including hashtags): ")
    predict_success(model, data_loader.tokenizer, image_path, caption)
# Out:
# Streaming output truncated to the last 5000 lines.
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/428429672_942836980774796_812393592432183790_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=108&_nc_ohc=WNWZb8ZWCZYAX9n3sR4&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC54ifMBrz7erxby6S9LIGFuyxLXSglCwPCMc29gmmteA&oe=65E756ED&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/428429672_942836980774796_812393592432183790_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=108&_nc_ohc=WNWZb8ZWCZYAX9n3sR4&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC54ifMBrz7erxby6S9LIGFuyxLXSglCwPCMc29gmmteA&oe=65E756ED&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/428299369_1818219725290887_8753604251804594968_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=gqX0mQnghCoAX8Ja3s7&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD_J0F3UeeWbFARcUXgPLt__vexDQtHzzIUOt6XB1JhtQ&oe=65E72686&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/428299369_1818219725290887_8753604251804594968_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=gqX0mQnghCoAX8Ja3s7&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD_J0F3UeeWbFARcUXgPLt__vexDQtHzzIUOt6XB1JhtQ&oe=65E72686&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/427931182_934551991716238_16226627302672276_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=qtOCdm_-7sMAX9yjg65&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBfosqsevJQiPQC1XZ8fVMTFLzoen2HOZLVXDtLp5h0KA&oe=65E73774&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/427931182_934551991716238_16226627302672276_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=qtOCdm_-7sMAX9yjg65&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBfosqsevJQiPQC1XZ8fVMTFLzoen2HOZLVXDtLp5h0KA&oe=65E73774&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/427938688_702559738416616_4894145019174408099_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=104&_nc_ohc=QnQjaIVl07EAX-U5WE9&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDv88QV7_yH6A6kavFjC9WHI-KxXtdI-qixujInS47jaw&oe=65E6C93A&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/427938688_702559738416616_4894145019174408099_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=104&_nc_ohc=QnQjaIVl07EAX-U5WE9&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDv88QV7_yH6A6kavFjC9WHI-KxXtdI-qixujInS47jaw&oe=65E6C93A&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/431057613_1094457494928477_3319287792605010116_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=1Hv5rTFqEbkAX8EXgKS&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfA_pHxIgpEo3neM8yWsdCtaGnMWL6IHIa9S_NhRYt1ODg&oe=65EAA82F&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/431057613_1094457494928477_3319287792605010116_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=1Hv5rTFqEbkAX8EXgKS&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfA_pHxIgpEo3neM8yWsdCtaGnMWL6IHIa9S_NhRYt1ODg&oe=65EAA82F&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/430266658_7877734142256554_6369847369750977592_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=OcdUlEd2X7wAX9cJBun&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBgXeWLvybMWF8_XO_DlrUC3SV4jy__-QdmZeAXKipukw&oe=65E9E278&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/430266658_7877734142256554_6369847369750977592_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=OcdUlEd2X7wAX9cJBun&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBgXeWLvybMWF8_XO_DlrUC3SV4jy__-QdmZeAXKipukw&oe=65E9E278&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/430034810_3248786315427614_6385804387791649646_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=fvehiSKMd8IAX-NrasN&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCGNKTBsZlijQdLUSVEwMXQGu32816OSppekUdzda5_rQ&oe=65E70C3B&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/430034810_3248786315427614_6385804387791649646_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=fvehiSKMd8IAX-NrasN&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCGNKTBsZlijQdLUSVEwMXQGu32816OSppekUdzda5_rQ&oe=65E70C3B&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429894553_1343887869690828_1226111150489685842_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=U_u52JNsTfUAX9xT_mJ&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBVKMYF_BEdcnCPQrlxmGhFiJPDGMBrsZWmQVIwot6usQ&oe=65E73C78&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429894553_1343887869690828_1226111150489685842_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=U_u52JNsTfUAX9xT_mJ&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBVKMYF_BEdcnCPQrlxmGhFiJPDGMBrsZWmQVIwot6usQ&oe=65E73C78&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429805002_3248464445462436_8315471595543096688_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=_Y0YaU682aUAX-OgE1O&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDFNMwBEifEpcQbyufY2JxS8KsIKoA130qN98sbp-0PDQ&oe=65E7517C&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429805002_3248464445462436_8315471595543096688_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=_Y0YaU682aUAX-OgE1O&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDFNMwBEifEpcQbyufY2JxS8KsIKoA130qN98sbp-0PDQ&oe=65E7517C&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429782547_1137409024357916_6315091589248546980_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=108&_nc_ohc=3o80aBDxiDkAX8hc-V-&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBUPFOAUy9Zf0XoyAO01sEGlii9QW4L1BsaMg-OHCk8tw&oe=65E7474C&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429782547_1137409024357916_6315091589248546980_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=108&_nc_ohc=3o80aBDxiDkAX8hc-V-&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBUPFOAUy9Zf0XoyAO01sEGlii9QW4L1BsaMg-OHCk8tw&oe=65E7474C&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429459819_1750965272074799_4736183925277224839_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=CYQvYmTEEYMAX_g7YHc&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfB9V3YJXsIrsd_2kplfLwsN_9X7b03xRcLM0XQS3Y76UA&oe=65E72114&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429459819_1750965272074799_4736183925277224839_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=CYQvYmTEEYMAX_g7YHc&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfB9V3YJXsIrsd_2kplfLwsN_9X7b03xRcLM0XQS3Y76UA&oe=65E72114&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429304982_431698752856079_9048378919733310649_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=bEmAqAZzuCgAX8GDuFH&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDaWgY8RMJ1TOiCo0vBdI1NgTTPQpsV7Y0noHsXniiKjQ&oe=65E75FA4&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429304982_431698752856079_9048378919733310649_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=bEmAqAZzuCgAX8GDuFH&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDaWgY8RMJ1TOiCo0vBdI1NgTTPQpsV7Y0noHsXniiKjQ&oe=65E75FA4&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429330467_364442736478485_2701735264363655246_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=obYYOelFgccAX91JBT0&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAFB96WyZX4G6xMRp8fvO7XEIxMVZGUHTk-jr4QLGStQg&oe=65E6E6D1&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/429330467_364442736478485_2701735264363655246_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=obYYOelFgccAX91JBT0&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAFB96WyZX4G6xMRp8fvO7XEIxMVZGUHTk-jr4QLGStQg&oe=65E6E6D1&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/428304440_969951757886816_5290342018510024330_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=108&_nc_ohc=bL9Z8_ooTw4AX8wW25U&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCcK7p4CwAm90GWn6pfMyNvPsMqzAB9_s7vNwhkCYTluA&oe=65E75762&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/428304440_969951757886816_5290342018510024330_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=108&_nc_ohc=bL9Z8_ooTw4AX8wW25U&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCcK7p4CwAm90GWn6pfMyNvPsMqzAB9_s7vNwhkCYTluA&oe=65E75762&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/426225629_937391421062210_5295374270730375569_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=sl7lnj1jjUUAX-2LxL3&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBm0-5_Jd5eNEwMQCA4LX5Y3171d3mn7B_q3-RBhzKV9Q&oe=65E75C88&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/426225629_937391421062210_5295374270730375569_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=sl7lnj1jjUUAX-2LxL3&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBm0-5_Jd5eNEwMQCA4LX5Y3171d3mn7B_q3-RBhzKV9Q&oe=65E75C88&_nc_sid=8b3546'
# Error loading image https://instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/425341003_1137427957430530_6264324788212742564_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=xjvI-JhCPeQAX-9zbIi&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCBJ9abB6d8nbc_G94c9mA1VGqfMenD382l3NSOVyexSQ&oe=65E71386&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.fasu4-1.fna.fbcdn.net/v/t51.2885-15/425341003_1137427957430530_6264324788212742564_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.fasu4-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=xjvI-JhCPeQAX-9zbIi&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCBJ9abB6d8nbc_G94c9mA1VGqfMenD382l3NSOVyexSQ&oe=65E71386&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/431137899_936234971545528_4900168789755990528_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=1&_nc_ohc=q8GEpSDHEkoAX-oQDNt&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCd9N4I0glnPfG-BZ-WF84swDybdnMvrRT2x8PoubeTOg&oe=65EA6782&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/431137899_936234971545528_4900168789755990528_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=1&_nc_ohc=q8GEpSDHEkoAX-oQDNt&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCd9N4I0glnPfG-BZ-WF84swDybdnMvrRT2x8PoubeTOg&oe=65EA6782&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/431223192_252948547901452_6587450466818573655_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=104&_nc_ohc=JRwQjfiAXYEAX8E-Bx8&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBTmfuKQqCujx0tDXhhZWNlsaryaIEdtQ7RKnkzoh96QQ&oe=65EB1711&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/431223192_252948547901452_6587450466818573655_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=104&_nc_ohc=JRwQjfiAXYEAX8E-Bx8&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBTmfuKQqCujx0tDXhhZWNlsaryaIEdtQ7RKnkzoh96QQ&oe=65EB1711&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/430494332_1753035041857984_6362233877818125753_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=104&_nc_ohc=FFLXvMnVsX8AX8M00gC&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDv4YC-ZZaINks0mzvHmjwx-9DDrSsHpCynafO6IXh7tA&oe=65E76C92&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/430494332_1753035041857984_6362233877818125753_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=104&_nc_ohc=FFLXvMnVsX8AX8M00gC&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDv4YC-ZZaINks0mzvHmjwx-9DDrSsHpCynafO6IXh7tA&oe=65E76C92&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/429453260_261684580215422_1723679293037390771_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=102&_nc_ohc=jKDRN9bY3p8AX-mIu2Z&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBZ0TVzAFvWvzdpiZ7PioEwNLwNp4sgeBDiAOTWwBYPBg&oe=65E9FCCD&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/429453260_261684580215422_1723679293037390771_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=102&_nc_ohc=jKDRN9bY3p8AX-mIu2Z&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBZ0TVzAFvWvzdpiZ7PioEwNLwNp4sgeBDiAOTWwBYPBg&oe=65E9FCCD&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/429481178_364760713070186_8721224819403853642_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=102&_nc_ohc=uSbkFQXHUfAAX-aYjEi&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC-6lKwwIpuvUVcEkNdaFplLLln0DHkP4rWtYsdObVgQQ&oe=65E9E447&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/429481178_364760713070186_8721224819403853642_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=102&_nc_ohc=uSbkFQXHUfAAX-aYjEi&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC-6lKwwIpuvUVcEkNdaFplLLln0DHkP4rWtYsdObVgQQ&oe=65E9E447&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/429337019_2558741047622181_2291001168503794360_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=109&_nc_ohc=5ho2v3tEt6MAX-mFMTL&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBTT_8m7AhrEhgAN_eDWpOTKzGTgIoeBF-N8U0HqShPkg&oe=65EA2401&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/429337019_2558741047622181_2291001168503794360_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=109&_nc_ohc=5ho2v3tEt6MAX-mFMTL&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBTT_8m7AhrEhgAN_eDWpOTKzGTgIoeBF-N8U0HqShPkg&oe=65EA2401&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/420571240_937202544172840_3810783256118257966_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=104&_nc_ohc=1M5bTFbMgZsAX8cyHZg&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBR0u21BWV5RhEfskTcFFXslkH8CP4-56tUPtTQvilWAg&oe=65E997C1&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/420571240_937202544172840_3810783256118257966_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=104&_nc_ohc=1M5bTFbMgZsAX8cyHZg&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBR0u21BWV5RhEfskTcFFXslkH8CP4-56tUPtTQvilWAg&oe=65E997C1&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/409089308_336857398701082_8182186861007832610_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=110&_nc_ohc=vzn6ez1j4JgAX-fn8tT&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfApGNq9yHmwxxO6C4c2nL1fiRRtgUKsrajxGCscoSRezw&oe=65E6F6E8&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/409089308_336857398701082_8182186861007832610_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=110&_nc_ohc=vzn6ez1j4JgAX-fn8tT&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfApGNq9yHmwxxO6C4c2nL1fiRRtgUKsrajxGCscoSRezw&oe=65E6F6E8&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/428291566_1445867419357409_4867588501290105660_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=105&_nc_ohc=AbtZ1xdXPR0AX_4Saba&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD-2s-4Aj0OlUodp6HDD8lXv8YL0HXjbnL0ACFEh7gRZQ&oe=65EAAEFB&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/428291566_1445867419357409_4867588501290105660_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=105&_nc_ohc=AbtZ1xdXPR0AX_4Saba&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD-2s-4Aj0OlUodp6HDD8lXv8YL0HXjbnL0ACFEh7gRZQ&oe=65EAAEFB&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/427357557_934250254956222_3684606665371089557_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=106&_nc_ohc=tnSeARndlfUAX_gqYyW&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD-kzgXNqIgR2K2q9OBOXuSULHkBOKDdW7S4KbhtcVGVw&oe=65E9B927&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/427357557_934250254956222_3684606665371089557_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=106&_nc_ohc=tnSeARndlfUAX_gqYyW&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD-kzgXNqIgR2K2q9OBOXuSULHkBOKDdW7S4KbhtcVGVw&oe=65E9B927&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/426972057_479554774398987_5767890465062286998_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=103&_nc_ohc=tkJpdgSBP5QAX9mAMmE&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC4LNTT-SCShObyNL5zYKNKOYnLV0DRfb-nP_kxVkvxVQ&oe=65EB3E06&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/426972057_479554774398987_5767890465062286998_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=103&_nc_ohc=tkJpdgSBP5QAX9mAMmE&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC4LNTT-SCShObyNL5zYKNKOYnLV0DRfb-nP_kxVkvxVQ&oe=65EB3E06&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/427762568_897441405413406_8983275580085517769_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=106&_nc_ohc=LGb7fJXpRAsAX_JmsOF&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfA3bQXDwsnd54DqsPSP7EX_my7csAolC41LowLAe70M-g&oe=65EA0CEE&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/427762568_897441405413406_8983275580085517769_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=106&_nc_ohc=LGb7fJXpRAsAX_JmsOF&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfA3bQXDwsnd54DqsPSP7EX_my7csAolC41LowLAe70M-g&oe=65EA0CEE&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/380821204_259304043152858_3670350454405652980_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=bj3uKSUyJM0AX_6DE8h&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCcHAdkbDVIloxyMZTgR4pfJGJ-FVUgSJ5NkoHnHKtqZQ&oe=65EA5FAF&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/380821204_259304043152858_3670350454405652980_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=bj3uKSUyJM0AX_6DE8h&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCcHAdkbDVIloxyMZTgR4pfJGJ-FVUgSJ5NkoHnHKtqZQ&oe=65EA5FAF&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/376271556_950425546024104_3116534020317065678_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=cGFSxjlK1CgAX8V0P-m&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBUt7P9hX2FdsHxrXsx6rAayZQxt6DRsaJgJaAieU28nA&oe=65E985ED&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/376271556_950425546024104_3116534020317065678_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=cGFSxjlK1CgAX8V0P-m&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBUt7P9hX2FdsHxrXsx6rAayZQxt6DRsaJgJaAieU28nA&oe=65E985ED&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/375281819_695819989058642_7487498507917453384_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=Pcs9ziX-BCUAX9bRp5o&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAp2IPj3a82YxS_sCv8fkFsDzpuz4rkaYB_srTcmTPSKw&oe=65E96D13&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/375281819_695819989058642_7487498507917453384_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=Pcs9ziX-BCUAX9bRp5o&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAp2IPj3a82YxS_sCv8fkFsDzpuz4rkaYB_srTcmTPSKw&oe=65E96D13&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/368677586_139072665917472_387805183155335594_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=DT2CZaKU2OgAX8keqXo&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDBF4WXSESrqg30emYupVxav4Yd3pSYGj6tWXiUyDFA6g&oe=65EAABA7&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/368677586_139072665917472_387805183155335594_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=DT2CZaKU2OgAX8keqXo&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDBF4WXSESrqg30emYupVxav4Yd3pSYGj6tWXiUyDFA6g&oe=65EAABA7&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/367695946_1781392145638134_6654515676072237652_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=1ilrqB1svjIAX9VSOnW&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCTI7HhZ-mhbDb3j7JcV8P8LexgIguSeG6cIrwGJmmXbg&oe=65EAC23E&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/367695946_1781392145638134_6654515676072237652_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=1ilrqB1svjIAX9VSOnW&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCTI7HhZ-mhbDb3j7JcV8P8LexgIguSeG6cIrwGJmmXbg&oe=65EAC23E&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/364298259_1076146260035369_2864879638240385380_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=105&_nc_ohc=uaLT3hXBU1cAX9H3vkn&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD5EG3Gji0divLn7-_kajRo13QnHg2LwkT3F3USh7845w&oe=65E9C62B&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/364298259_1076146260035369_2864879638240385380_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=105&_nc_ohc=uaLT3hXBU1cAX9H3vkn&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD5EG3Gji0divLn7-_kajRo13QnHg2LwkT3F3USh7845w&oe=65E9C62B&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/341919244_202503609229898_1414162433353425548_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=P0Z6SBPE_bgAX-Csm9e&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDUr_-nL9bijk_F1mp5Dq4lrlYYMzcmo62LB_PqV-Gv8w&oe=65EA9062&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/341919244_202503609229898_1414162433353425548_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=P0Z6SBPE_bgAX-Csm9e&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDUr_-nL9bijk_F1mp5Dq4lrlYYMzcmo62LB_PqV-Gv8w&oe=65EA9062&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/341180556_674306491129888_5654698302433695208_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=104&_nc_ohc=ImUE_yhZJIAAX85ZiJI&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC6nk7ftg6Ee8ODyFnMv4nV09BE9S3QulLXZwO_64Ig_A&oe=65E6E669&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/341180556_674306491129888_5654698302433695208_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=104&_nc_ohc=ImUE_yhZJIAAX85ZiJI&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC6nk7ftg6Ee8ODyFnMv4nV09BE9S3QulLXZwO_64Ig_A&oe=65E6E669&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/341146532_1269503027250126_8254135137893116540_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=cMnq_9tpuy4AX9yxrgJ&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfANZBt2kAckP47tjaaFBTJsvHSzPxhNpAhVJOAGB92FLg&oe=65EB0DFD&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/341146532_1269503027250126_8254135137893116540_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=cMnq_9tpuy4AX9yxrgJ&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfANZBt2kAckP47tjaaFBTJsvHSzPxhNpAhVJOAGB92FLg&oe=65EB0DFD&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/321483440_1527208277791715_5208626168849195534_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=AfHWZVdhaWcAX-a_g2f&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBFhVn8nPDIVtVQ1IJbMaEdciQpo-rhbgIoNXtPTM05yw&oe=65EA76D3&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/321483440_1527208277791715_5208626168849195534_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=111&_nc_ohc=AfHWZVdhaWcAX-a_g2f&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBFhVn8nPDIVtVQ1IJbMaEdciQpo-rhbgIoNXtPTM05yw&oe=65EA76D3&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/325682038_1369064540533454_2902862209842774924_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=tIS2b0ljwBcAX--FeOv&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCX8YXHE5t-kDTIVrxMYWr6WOr_BtdPZiIOGXAjS8B2LA&oe=65EB253C&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/325682038_1369064540533454_2902862209842774924_n.webp?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=tIS2b0ljwBcAX--FeOv&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCX8YXHE5t-kDTIVrxMYWr6WOr_BtdPZiIOGXAjS8B2LA&oe=65EB253C&_nc_sid=8b3546'
# Error loading image https://instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/153567815_796622864543169_8729433292012566310_n.jpg?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=c4XW7NQlg1IAX_UtIXr&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBJfxW1XuuvxUyCFJ_fGFnwM_BwBBi0JIdZ6Nbe-801kg&oe=65EB1AB0&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.foua5-1.fna.fbcdn.net/v/t51.2885-15/153567815_796622864543169_8729433292012566310_n.jpg?stp=dst-jpg_e35&_nc_ht=instagram.foua5-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=c4XW7NQlg1IAX_UtIXr&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBJfxW1XuuvxUyCFJ_fGFnwM_BwBBi0JIdZ6Nbe-801kg&oe=65EB1AB0&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/343053709_946367396563399_1684995691447580550_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=107&_nc_ohc=exyNxwrJhd0AX9M8R2Q&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAdTHo_PblOdgfq5FGpy4UvCA0-51tSFLAhv1qw6z20PA&oe=65E71178&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/343053709_946367396563399_1684995691447580550_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=107&_nc_ohc=exyNxwrJhd0AX9M8R2Q&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAdTHo_PblOdgfq5FGpy4UvCA0-51tSFLAhv1qw6z20PA&oe=65E71178&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/360189998_817022993047506_5678446872385471129_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=106&_nc_ohc=1WLU3ZSnBfQAX8jgSfN&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDWGeAX0KAeChZE3DOMPSq2oTyqlFNXLo0eMpoOLU8LCA&oe=65E6EC39&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/360189998_817022993047506_5678446872385471129_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=106&_nc_ohc=1WLU3ZSnBfQAX8jgSfN&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDWGeAX0KAeChZE3DOMPSq2oTyqlFNXLo0eMpoOLU8LCA&oe=65E6EC39&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/334781593_160582966805609_8766604722748750276_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=105&_nc_ohc=3NM0CdV7s5MAX8S8KWP&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDGQwaMJ2G53KpB2VouwGayPc66kVwo4zgYYPstOcVf0g&oe=65E70E07&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/334781593_160582966805609_8766604722748750276_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=105&_nc_ohc=3NM0CdV7s5MAX8S8KWP&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDGQwaMJ2G53KpB2VouwGayPc66kVwo4zgYYPstOcVf0g&oe=65E70E07&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/429803568_726235346302691_6267246736743471718_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=111&_nc_ohc=JpRHmDVZsHsAX8_tVb8&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBgTQ45cCMsP54unmrIlRaND4KdU4QZuOK3ikr014SQPg&oe=65E6E1BB&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/429803568_726235346302691_6267246736743471718_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=111&_nc_ohc=JpRHmDVZsHsAX8_tVb8&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBgTQ45cCMsP54unmrIlRaND4KdU4QZuOK3ikr014SQPg&oe=65E6E1BB&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/409030012_358933770339933_9044857716020688529_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=109&_nc_ohc=i6Wa7xEa9TkAX8HEoZh&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC_CVQfw7mIKPxGPjOWGHXZfuFNtl7YQUbC5jXqhe31vA&oe=65E74E03&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/409030012_358933770339933_9044857716020688529_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=109&_nc_ohc=i6Wa7xEa9TkAX8HEoZh&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC_CVQfw7mIKPxGPjOWGHXZfuFNtl7YQUbC5jXqhe31vA&oe=65E74E03&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/429170413_369631812528409_3324708481028354288_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=101&_nc_ohc=zLdAuxmNZJMAX9nbIWO&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDZwc9l_TVqIylq1oaqMVAC_cE-YWoQlI3YOxj1RpuwZw&oe=65E6CC6F&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/429170413_369631812528409_3324708481028354288_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=101&_nc_ohc=zLdAuxmNZJMAX9nbIWO&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDZwc9l_TVqIylq1oaqMVAC_cE-YWoQlI3YOxj1RpuwZw&oe=65E6CC6F&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/420576296_1408592610045207_3103510980942606529_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=103&_nc_ohc=RcInq9K0_B4AX9D9X4D&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDvb7OySvtGsj-s54u3SFQ4C_DJ0l0ng4o0WLrIkBxeGA&oe=65E71042&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/420576296_1408592610045207_3103510980942606529_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=103&_nc_ohc=RcInq9K0_B4AX9D9X4D&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDvb7OySvtGsj-s54u3SFQ4C_DJ0l0ng4o0WLrIkBxeGA&oe=65E71042&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/429194448_961689452051739_3465836243496067602_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=103&_nc_ohc=pcJpV82PswwAX8yJZS5&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD_FiLbwxjLETqj_GVdq39idHJViTgL-X76hoIkYMjsxQ&oe=65E6F34F&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/429194448_961689452051739_3465836243496067602_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=103&_nc_ohc=pcJpV82PswwAX8yJZS5&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD_FiLbwxjLETqj_GVdq39idHJViTgL-X76hoIkYMjsxQ&oe=65E6F34F&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/427606845_1447674799513630_8298450433067635343_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=110&_nc_ohc=Xh9As_ad6e4AX80TNXu&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAAhBsmM6lhDPEvOeQK6vCkWMlSd4ix8-DQ-yOl_BmMqg&oe=65E74DB6&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/427606845_1447674799513630_8298450433067635343_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=110&_nc_ohc=Xh9As_ad6e4AX80TNXu&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAAhBsmM6lhDPEvOeQK6vCkWMlSd4ix8-DQ-yOl_BmMqg&oe=65E74DB6&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/427829162_359533480229183_7456129530847357923_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=111&_nc_ohc=NPfjHqDbigcAX8qzQlw&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAIhCqMm-8i3fq632o45tfNRVvUahX7Ofnm_aDtsOpDjA&oe=65E6E88F&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/427829162_359533480229183_7456129530847357923_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=111&_nc_ohc=NPfjHqDbigcAX8qzQlw&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAIhCqMm-8i3fq632o45tfNRVvUahX7Ofnm_aDtsOpDjA&oe=65E6E88F&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/427014735_1296384281205786_2900890112616700394_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=106&_nc_ohc=K0DMeYR0XvQAX8y5u06&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfB34yZQElhAWJi9npZrR8WmPce2-tIyAYz3cJ4xOz9s5Q&oe=65EA19CB&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/427014735_1296384281205786_2900890112616700394_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=106&_nc_ohc=K0DMeYR0XvQAX8y5u06&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfB34yZQElhAWJi9npZrR8WmPce2-tIyAYz3cJ4xOz9s5Q&oe=65EA19CB&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/426741779_2344906192346581_3305230711966750677_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=101&_nc_ohc=xhT19WeBc_YAX8QSZaq&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBdDL8JvfFl3COUOLb6p0xtIV2T8kuoB9JSI053TsQdeQ&oe=65EA1918&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/426741779_2344906192346581_3305230711966750677_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=101&_nc_ohc=xhT19WeBc_YAX8QSZaq&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBdDL8JvfFl3COUOLb6p0xtIV2T8kuoB9JSI053TsQdeQ&oe=65EA1918&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/274847120_3170389659915357_5444414160346386835_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=109&_nc_ohc=gQpc4Uki9M0AX_5UsTz&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCjj6qli7uXJppPAIUY-vfdS8blVgBrKTA_d_LbsCxaPQ&oe=65EB4CCD&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/274847120_3170389659915357_5444414160346386835_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=109&_nc_ohc=gQpc4Uki9M0AX_5UsTz&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCjj6qli7uXJppPAIUY-vfdS8blVgBrKTA_d_LbsCxaPQ&oe=65EB4CCD&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/274380098_646388733336059_4173098505299726203_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=111&_nc_ohc=3zmxMvifKGsAX8TMVfO&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfB2jvnyMf4oBk-4ymWDUF_DewLYKG8N9oi00uUDg8DVsQ&oe=65E97EDC&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/274380098_646388733336059_4173098505299726203_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=111&_nc_ohc=3zmxMvifKGsAX8TMVfO&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfB2jvnyMf4oBk-4ymWDUF_DewLYKG8N9oi00uUDg8DVsQ&oe=65E97EDC&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/274075264_645035026831383_4524022830853993919_n.jpg?stp=dst-jpg_e35_s1080x1080&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=103&_nc_ohc=Q0JdUM_3wKEAX93uhpY&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCIMlNnuZ49IRCDts5HwQUe3j-tJjbEJqFpnUiTNuVMbQ&oe=65EB5529&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/274075264_645035026831383_4524022830853993919_n.jpg?stp=dst-jpg_e35_s1080x1080&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=103&_nc_ohc=Q0JdUM_3wKEAX93uhpY&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCIMlNnuZ49IRCDts5HwQUe3j-tJjbEJqFpnUiTNuVMbQ&oe=65EB5529&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/273624099_110410508226337_4670146136778554929_n.jpg?stp=dst-jpg_e35_s1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=101&_nc_ohc=kNq1pISvdA8AX_QtncW&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD6zuerQ9ykjbkuuhOoeOfLMUSjarEuZhbKJyXe26hp8g&oe=65E9BD83&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-2.cdninstagram.com/v/t51.2885-15/273624099_110410508226337_4670146136778554929_n.jpg?stp=dst-jpg_e35_s1080x1080&_nc_ht=scontent-lhr8-2.cdninstagram.com&_nc_cat=101&_nc_ohc=kNq1pISvdA8AX_QtncW&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfD6zuerQ9ykjbkuuhOoeOfLMUSjarEuZhbKJyXe26hp8g&oe=65E9BD83&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/272677686_258328869774814_8873088960978517650_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=110&_nc_ohc=g00LGJO8R_4AX-mep1D&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBu2E0K6zt2HoQn_2IcwJRvst9BJ-OQz6SxZMzUP5pZJQ&oe=65E96C24&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/272677686_258328869774814_8873088960978517650_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=110&_nc_ohc=g00LGJO8R_4AX-mep1D&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBu2E0K6zt2HoQn_2IcwJRvst9BJ-OQz6SxZMzUP5pZJQ&oe=65E96C24&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/272184144_3129673017318336_6916331611793735157_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=100&_nc_ohc=SzYxkXx5wHoAX93fgjn&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC45b8gYsxWpXxkHgT1FRhPGwMerJKCUuM2UKn1eUDtYQ&oe=65EB3F96&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/272184144_3129673017318336_6916331611793735157_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=100&_nc_ohc=SzYxkXx5wHoAX93fgjn&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfC45b8gYsxWpXxkHgT1FRhPGwMerJKCUuM2UKn1eUDtYQ&oe=65EB3F96&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/271820657_958574688365786_4332026025252707984_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=102&_nc_ohc=VY_-UN1g2_4AX8RBPuM&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBLO-uCqDFHXSe8jNwqa6JR47ZdWIDvCvKDP-80frFNAQ&oe=65E9EFF9&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/271820657_958574688365786_4332026025252707984_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=102&_nc_ohc=VY_-UN1g2_4AX8RBPuM&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBLO-uCqDFHXSe8jNwqa6JR47ZdWIDvCvKDP-80frFNAQ&oe=65E9EFF9&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/271811973_1277617562720316_1918900127971025122_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=100&_nc_ohc=g24iWCaPFOwAX9n3_fD&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBeWZITF_xtldLOgR4Y5x8FQ_cz1tB55J6n-oCCUTyT6g&oe=65EA71E6&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/271811973_1277617562720316_1918900127971025122_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=100&_nc_ohc=g24iWCaPFOwAX9n3_fD&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBeWZITF_xtldLOgR4Y5x8FQ_cz1tB55J6n-oCCUTyT6g&oe=65EA71E6&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/271552174_1008498253345608_3729375646545845161_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=100&_nc_ohc=sAWqXo24EREAX_WZ8ER&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAWopM0NHRR9kXutmsp8NI8-2lMrOkPH7ftSeDeSONx9A&oe=65E98F01&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/271552174_1008498253345608_3729375646545845161_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=100&_nc_ohc=sAWqXo24EREAX_WZ8ER&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfAWopM0NHRR9kXutmsp8NI8-2lMrOkPH7ftSeDeSONx9A&oe=65E98F01&_nc_sid=8b3546'
# Error loading image https://scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/271513509_445819267019851_8576994123517542225_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=107&_nc_ohc=fmF_pALldk8AX_e_Cik&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCs6686EJP3a8jQr5JTdhGcgIUwed5ox_rHE3C0gx6t4Q&oe=65E9A300&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr8-1.cdninstagram.com/v/t51.2885-15/271513509_445819267019851_8576994123517542225_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr8-1.cdninstagram.com&_nc_cat=107&_nc_ohc=fmF_pALldk8AX_e_Cik&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCs6686EJP3a8jQr5JTdhGcgIUwed5ox_rHE3C0gx6t4Q&oe=65E9A300&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/271450814_265057725561840_7713973091387368234_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=100&_nc_ohc=VYPqMVFNy7YAX8dRg1b&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCqBQP_5VPdPkFJA2wlrUUXyov-DMBX0JVrafUvyyWePA&oe=65E9AF56&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-2.cdninstagram.com/v/t51.2885-15/271450814_265057725561840_7713973091387368234_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=100&_nc_ohc=VYPqMVFNy7YAX8dRg1b&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfCqBQP_5VPdPkFJA2wlrUUXyov-DMBX0JVrafUvyyWePA&oe=65E9AF56&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/271304576_468084131369470_1696895860446893761_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=110&_nc_ohc=GnsaSMYIZUcAX-bLT1p&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBm1S7FA6O5sn2WW7V3wqGd9mDoqrXLWlKisCz4p-jXYA&oe=65EAA89C&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/271304576_468084131369470_1696895860446893761_n.jpg?stp=dst-jpg_e35_p1080x1080&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=110&_nc_ohc=GnsaSMYIZUcAX-bLT1p&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBm1S7FA6O5sn2WW7V3wqGd9mDoqrXLWlKisCz4p-jXYA&oe=65EAA89C&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/430715507_429476456411546_2288442787435965822_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=102&_nc_ohc=qJkEHpdaJxUAX9qA1_-&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBhrs1SDTbOLwC2BwDSJb_lQk8sUHHgu97GpiXOGskyJQ&oe=65E6F24D&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-1.cdninstagram.com/v/t51.2885-15/430715507_429476456411546_2288442787435965822_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-lhr6-1.cdninstagram.com&_nc_cat=102&_nc_ohc=qJkEHpdaJxUAX9qA1_-&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBhrs1SDTbOLwC2BwDSJb_lQk8sUHHgu97GpiXOGskyJQ&oe=65E6F24D&_nc_sid=8b3546'
# Error loading image https://scontent-lhr6-2.cdninstagram.com/v/t39.30808-6/409036707_18417382465012805_3996194724841812246_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=105&_nc_ohc=oPI3SQDqC_gAX_1sBQb&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfA49FXNzC-oy3RZaonjXe67CD9SlMv-K-stUvvagFXZTA&oe=65EA7E8B&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/scontent-lhr6-2.cdninstagram.com/v/t39.30808-6/409036707_18417382465012805_3996194724841812246_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=scontent-lhr6-2.cdninstagram.com&_nc_cat=105&_nc_ohc=oPI3SQDqC_gAX_1sBQb&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfA49FXNzC-oy3RZaonjXe67CD9SlMv-K-stUvvagFXZTA&oe=65EA7E8B&_nc_sid=8b3546'
# ...
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/424977329_18428751049033498_5963976541110860937_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=cIMDMrBJ7lsAX-3EkD3&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfDy2PY9HrhoztUF44ALwfGkJP1sN2JWC4fzDMbjAD_siA&oe=65EA9118&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/424977329_18428751049033498_5963976541110860937_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=cIMDMrBJ7lsAX-3EkD3&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfDy2PY9HrhoztUF44ALwfGkJP1sN2JWC4fzDMbjAD_siA&oe=65EA9118&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/421965934_18427639957033498_4427872172543568704_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=DPiAmkiMHBMAX9Jo38n&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfC0b3Zjr3U1McCtgone-vnod2CN6vZRC3-nBlPOnuvgdw&oe=65EA683B&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/421965934_18427639957033498_4427872172543568704_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=DPiAmkiMHBMAX9Jo38n&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfC0b3Zjr3U1McCtgone-vnod2CN6vZRC3-nBlPOnuvgdw&oe=65EA683B&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/421960259_18427451938033498_7555846047269146346_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=Kra8V8GApK4AX-EMOMs&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfBD9xMAlF48tb4U8hn-Xy-P-9NEfVsK0lkMlCD3CA_OZQ&oe=65EA247E&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/421960259_18427451938033498_7555846047269146346_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=Kra8V8GApK4AX-EMOMs&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfBD9xMAlF48tb4U8hn-Xy-P-9NEfVsK0lkMlCD3CA_OZQ&oe=65EA247E&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/421889535_18426024790033498_6592809327338324092_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=F89H2-bDAk4AX9rtGaB&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfDy64hbOM4vaKkvl_4Ch1s2hCRvbjVod51o6gRtDzxxIQ&oe=65EA9EB0&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/421889535_18426024790033498_6592809327338324092_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=F89H2-bDAk4AX9rtGaB&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfDy64hbOM4vaKkvl_4Ch1s2hCRvbjVod51o6gRtDzxxIQ&oe=65EA9EB0&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/421877029_18425925856033498_7471473775903243695_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=mhombSZMryQAX9smrWp&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfCBc_VphBsMxnWk3UaFSKbC_sG_4BIgd_jH7DZaEX4TvA&oe=65EAEF3B&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/421877029_18425925856033498_7471473775903243695_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=mhombSZMryQAX9smrWp&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfCBc_VphBsMxnWk3UaFSKbC_sG_4BIgd_jH7DZaEX4TvA&oe=65EAEF3B&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/421948038_764246731707462_2612462656835438450_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=YbWWutTqfdsAX-dEluf&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDL5izt-rompm-qODRLTeVRRVK5InaW8SpQz4OrB_hROA&oe=65E6E86C&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/421948038_764246731707462_2612462656835438450_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=YbWWutTqfdsAX-dEluf&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDL5izt-rompm-qODRLTeVRRVK5InaW8SpQz4OrB_hROA&oe=65E6E86C&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/420091335_18425475796033498_5396176977292926026_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=4ADeTleTmOYAX8W_B4A&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfBfghB1H-CdKT3G3BOZjL-TcrePCjNG7xXcOK366lzzLQ&oe=65E9E00A&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/420091335_18425475796033498_5396176977292926026_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=4ADeTleTmOYAX8W_B4A&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfBfghB1H-CdKT3G3BOZjL-TcrePCjNG7xXcOK366lzzLQ&oe=65E9E00A&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/422324275_1798845587253970_6008137256073431088_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=CzAIpfcHo1wAX_vaDkX&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBCIhTXGoVJf4KPdfiNv4vCS-qT-Z_mPAxi7NnZoTV5zQ&oe=65E702EF&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/422324275_1798845587253970_6008137256073431088_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=CzAIpfcHo1wAX_vaDkX&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBCIhTXGoVJf4KPdfiNv4vCS-qT-Z_mPAxi7NnZoTV5zQ&oe=65E702EF&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/420062483_18424866751033498_8830987300482468564_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=61NdxG3yLx4AX_393G1&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfB6DMbQM6YridIoSxHa3irPCA1n58YwFW0zDW7xF1NUfw&oe=65EA1071&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/420062483_18424866751033498_8830987300482468564_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=61NdxG3yLx4AX_393G1&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfB6DMbQM6YridIoSxHa3irPCA1n58YwFW0zDW7xF1NUfw&oe=65EA1071&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/431559632_245725448607420_7744298389431145598_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=g3xHNROAuxAAX_IQwyN&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfA4eFbqw2wfWRduUeKKWsvySnOh4zU8T5TTO9e-IHyZkg&oe=65E6E9F3&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/431559632_245725448607420_7744298389431145598_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=g3xHNROAuxAAX_IQwyN&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfA4eFbqw2wfWRduUeKKWsvySnOh4zU8T5TTO9e-IHyZkg&oe=65E6E9F3&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/430471603_18418791262038720_7875565052217017717_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=eNWBdMNuhzcAX_qED4Q&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfC1ULmNkx5SS7Yqbt16fp0-PsIut3-d4htM1wGacDAmTQ&oe=65E98195&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/430471603_18418791262038720_7875565052217017717_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=eNWBdMNuhzcAX_qED4Q&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfC1ULmNkx5SS7Yqbt16fp0-PsIut3-d4htM1wGacDAmTQ&oe=65E98195&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/430029221_18418616260038720_4470439369617765725_n.jpg?stp=dst-jpg_e35_s1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=EDO8dyyUuXMAX8xDW_4&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfBFAvc1-jQoFbsZThdxz7YggJeuDCwUHScUXTB270WlBw&oe=65E9F681&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/430029221_18418616260038720_4470439369617765725_n.jpg?stp=dst-jpg_e35_s1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=EDO8dyyUuXMAX8xDW_4&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfBFAvc1-jQoFbsZThdxz7YggJeuDCwUHScUXTB270WlBw&oe=65E9F681&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/430023710_18417908320038720_3364825039332895153_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=h4-UpJA4k5UAX8wgovX&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfDnLRsYSSZ0jU-bIxB-jsInE1TJb9HN0keWj_EpoKV8xw&oe=65EAA741&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t39.30808-6/430023710_18417908320038720_3364825039332895153_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=h4-UpJA4k5UAX8wgovX&edm=AOQ1c0wAAAAA&ccb=7-5&oh=00_AfDnLRsYSSZ0jU-bIxB-jsInE1TJb9HN0keWj_EpoKV8xw&oe=65EAA741&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/429654430_1440423296831398_4471717258842341941_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=mhXCR7hG6QUAX8l-O-y&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfA-yrZ3b8JVcVKI3UEYN8HoDjL0LpG7aY9_X0kmEkBcFw&oe=65E73578&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/429654430_1440423296831398_4471717258842341941_n.jpg?stp=dst-jpg_e35_p1080x1080_sh0.08&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=mhXCR7hG6QUAX8l-O-y&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfA-yrZ3b8JVcVKI3UEYN8HoDjL0LpG7aY9_X0kmEkBcFw&oe=65E73578&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/428143442_284300634678310_2822800459973950966_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=4Qd0zExVrx8AX-poEkc&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDnhrvwb0SKgFZNRkDeZR8Z3t9NDDTHXkIs2Yjay65htQ&oe=65E72835&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/428143442_284300634678310_2822800459973950966_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=4Qd0zExVrx8AX-poEkc&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfDnhrvwb0SKgFZNRkDeZR8Z3t9NDDTHXkIs2Yjay65htQ&oe=65E72835&_nc_sid=8b3546'
# Error loading image https://instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/427020613_910481120630333_1213166851894379328_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=105&_nc_ohc=v3wHmF2ZkMsAX8ao-XD&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBXKmE2cMmrCZz7o1Lsop26VZxZvShjH7cK9qubNqcDMg&oe=65E6FFB2&_nc_sid=8b3546: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/427020613_910481120630333_1213166851894379328_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=105&_nc_ohc=v3wHmF2ZkMsAX8ao-XD&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBXKmE2cMmrCZz7o1Lsop26VZxZvShjH7cK9qubNqcDMg&oe=65E6FFB2&_nc_sid=8b3546'
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-26-513e71434662> in _load_image(self, image_path, image_size)
#      16         try:
# ---> 17             img = Image.open(f"{self.image_dir}/{image_path}").convert("RGB")
#      18             img = img.resize(image_size)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3430     if filename:
# -> 3431         fp = builtins.open(filename, "rb")
#    3432         exclusive_fp = True
#
# NotADirectoryError: [Errno 20] Not a directory: '/content/drive/MyDrive/instagram_data.csv/https:/instagram.flba2-1.fna.fbcdn.net/v/t51.2885-15/427020613_910481120630333_1213166851894379328_n.jpg?stp=dst-jpg_e15&_nc_ht=instagram.flba2-1.fna.fbcdn.net&_nc_cat=105&_nc_ohc=v3wHmF2ZkMsAX8ao-XD&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfBXKmE2cMmrCZz7o1Lsop26VZxZvShjH7cK9qubNqcDMg&oe=65E6FFB2&_nc_sid=8b3546'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-4a139bc61d16> in <cell line: 1>()
#       2     # Load data and create dataset
#       3     data_loader = DataLoader()
# ----> 4     dataset = data_loader.get_image_text_dataset()
#       5
#       6     # Build and train the model
#
# <ipython-input-26-513e71434662> in get_image_text_dataset(self, batch_size, image_size, max_words, max_length)
#      31
#      32     def get_image_text_dataset(self, batch_size=32, image_size=(224, 224), max_words=10000, max_length=100):
# ---> 33         images = [self._load_image(img_path, image_size) for img_path in self.images_path]
#      34         padded_sequences = self.prepare_text_data(max_words, max_length)
#      35
#
# <ipython-input-26-513e71434662> in <listcomp>(.0)
#      31
#      32     def get_image_text_dataset(self, batch_size=32, image_size=(224, 224), max_words=10000, max_length=100):
# ---> 33         images = [self._load_image(img_path, image_size) for img_path in self.images_path]
#      34         padded_sequences = self.prepare_text_data(max_words, max_length)
#      35
#
# <ipython-input-26-513e71434662> in _load_image(self, image_path, image_size)
#      20             return img_array
#      21         except Exception as e:
# ---> 22             print(f"Error loading image {image_path}: {e}")
#      23             return np.zeros((*image_size, 3))
#      24
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     618                 )
#     619             data.group = group
# --> 620         return super().send(data, flags=flags, copy=copy, track=track)
#     621
#     622     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.10/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
